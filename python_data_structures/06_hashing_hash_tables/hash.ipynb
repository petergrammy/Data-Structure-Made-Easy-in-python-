# %% [markdown]
# # Hash Tables

# %% [markdown]
# What is Hash table/hashing function ?
# - Hash Tables relate a value to a key, and then put it into an array.
# - In python, we use '''dict''' to achieve hash.
# - In this chapter we need to know how to use dict.
#
# The missions are as follows:
# - achieve hashing table algorithm by purly manual coding, basing on stack, queue, and so on.
# - state a proper case that can be solved with hashing function or hash table.

# %% [markdown]
# ## Writing a simple hash search:

# %%
class Simple_Dict:
    def __init__(self,size):
        self.size=size
        self.slot = [[] for _ in range(size)]

    def set(self,key,value):
        index = hash(key)%self.size
        bucket = self.slot[index]

        for i,(existing_key,existing_value) in enumerate(bucket):
            if key==existing_key:
                bucket[i]=(key,value)
                return
        
        bucket.append((key,value))

    def get(self,key)

# %%
## Put into use:

# d=Simple_Dict()
# d.set("524120910050",96)
# d.get('524120910050')
